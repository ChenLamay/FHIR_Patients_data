# %%
#pip install psycopg2-binary
#!pip install python-dateutil
#!pip install arrow
# Out:
# Requirement already satisfied: arrow in c:\users\chenl\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\chenl\anaconda3\lib\site-packages (from arrow) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\chenl\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->arrow) (1.16.0)

# %%
import pandas as pd
import json
import jsonlines
import re
import psycopg2
import sqlite3
from datetime import datetime
from psycopg2 import extras
from dateutil.parser import parse 
import arrow
import csv

# %%
# Fixing the JSON file
with open('fhir_encounters.jsonl', 'r') as file:
    data_str = ''.join(file.readlines())

index = data_str.find('sys_insert')

while index != -1:
    next_brace = data_str.find('}', index)
    if next_brace != -1:
        index = data_str.find('sys_insert', next_brace)
        if index != -1:
            data_str = data_str[:next_brace + 1] + ',' + data_str[next_brace + 1:]      
    else:
        break

json_fhir = "[{}]".format(data_str)
json_fhir = json.loads(json_fhir)

with open('fhir_encounters.json', 'w') as output_file:
    json.dump(json_fhir, output_file, indent=4)
    
json_fhir
# Out:
# [{'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3015', 'display': 'Lily Young'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F32.A',
#        'display': 'Depression, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:35:38.404169 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3026', 'display': 'Oliver White'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005', 'display': 'Dr. Sophia Garcia'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'J02.9',
#        'display': 'Acute pharyngitis, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:50:52.818241 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3007', 'display': 'William Taylor'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.9',
#        'display': 'Anxiety disorder, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 14:32:21.03577 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3008', 'display': 'Emma Anderson'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'R30.0',
#        'display': 'Dysuria',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:44:04.196978 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3025', 'display': 'Grace Walker'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005', 'display': 'Dr. Sophia Garcia'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.1',
#        'display': 'Generalized anxiety disorder',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 12:38:33.479699 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3006', 'display': 'Sophia Martinez'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2001', 'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'J01.90',
#        'display': 'Acute sinusitis, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 14:32:21.03577 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3002', 'display': 'Jane Doe'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.1',
#        'display': 'Generalized anxiety disorder',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 12:38:33.479699 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3006', 'display': 'Sophia Martinez'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'N76.0',
#        'display': 'Acute vaginitis',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:50:52.818241 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3004', 'display': 'Emily Johnson'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'B37.3',
#        'display': 'Candidiasis of vulva and vagina',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:44:04.196978 UTC'},
#  {'encounter': {'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 1,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3009', 'display': 'Daniel White'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred', 'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
#       'period': {'start': '2023-11-22T03:00:00Z',
#        '_end': '2023-11-22T03:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'N39.0',
#        'display': 'Urinary tract infection, site not specified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:35:38.404169 UTC'},
#  {'encounter': {'ecstatus': 'succeed',
#    'resourcetype': 'Bundle',
#    'type': 'searchset',
#    'total': 21,
#    'entry': [{'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/esdxwR-ztD6sosLI0PIgtTA8hMDql1R-cROdOiswSDR03',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'esdxwR-ztD6sosLI0PIgtTA8hMDql1R-cROdOiswSDR03',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3009', 'display': 'Daniel White'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-11-16T20:30:00Z',
#        '_end': '2023-11-16T20:45:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'K04.90',
#        'display': 'Unspecified diseases of pulp and periapical tissues',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ebcOcETKr6q3F1GkMUt48D4uOXOHJGsbXp3nlJXtskno3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'ebcOcETKr6q3F1GkMUt48D4uOXOHJGsbXp3nlJXtskno3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3036', 'display': 'Scarlett Johnson'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2001', 'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-11-06T18:45:00Z',
#        '_end': '2023-11-06T19:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'U07.1',
#        'display': 'COVID-19',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ec7u9.FNdhxp9XFKdyFg1gkEM1bAqea0HHIx4T0mVv3Y3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'ec7u9.FNdhxp9XFKdyFg1gkEM1bAqea0HHIx4T0mVv3Y3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3003', 'display': 'Michael Smith'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
#       'period': {'start': '2023-11-02T22:45:00Z',
#        '_end': '2023-11-02T23:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.9',
#        'display': 'Anxiety disorder, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/elTbgsTY2x.9jPVTyMFqWcVV.3YmLrkPf2uVgCd8-AxM3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'elTbgsTY2x.9jPVTyMFqWcVV.3YmLrkPf2uVgCd8-AxM3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3031', 'display': 'Madison Reed'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005',
#         'display': 'Dr. Sophia Garcia-Richardsנ'}],
#       'period': {'start': '2023-10-30T12:15:00Z',
#        '_end': '2023-10-30T12:30:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'I10',
#        'display': 'Essential (primary) hypertension',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ekMJg0H-ohv8r8ojv7E9SNIGcDxoLXVWVPdBB4k58odI3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'ekMJg0H-ohv8r8ojv7E9SNIGcDxoLXVWVPdBB4k58odI3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3008', 'display': 'Emma Anderson'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
#       'period': {'start': '2023-10-26T18:15:00Z',
#        '_end': '2023-10-26T18:30:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'R30.0',
#        'display': 'Dysuria',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eOT2GSmkI-CWRO-2Z.dbMtPkhM7RT4W6wOvuX6oTMWXE3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eOT2GSmkI-CWRO-2Z.dbMtPkhM7RT4W6wOvuX6oTMWXE3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3011', 'display': 'Liam Harris'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-10-23T21:00:00Z',
#        '_end': '2023-10-23T21:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F32.A',
#        'display': 'Depression, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/efP6ciuCLD6OkZT1u5Tb2I79igV1W91Gxc0cUQalyhyw3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'efP6ciuCLD6OkZT1u5Tb2I79igV1W91Gxc0cUQalyhyw3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'}],
#       'subject': {'reference': 'Patient3024', 'display': 'Elijah Davis'},
#       'participant': [{'reference': 'Practitioner/Dr2004',
#         'display': 'Dr. Ethan Fisher'}],
#       'period': {'start': '2023-09-15T14:45:00Z',
#        '_end': '2023-09-15T15:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'N52.9',
#        'display': 'Male erectile dysfunction, unspecified',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e5YGOZTIbBGutvJpRf0cyOwnCuqkB0ibPuc.qk2llK8Q3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'e5YGOZTIbBGutvJpRf0cyOwnCuqkB0ibPuc.qk2llK8Q3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3030', 'display': 'Landon Hayes'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2004', 'display': 'Dr. Ethan Fisher'}],
#       'period': {'start': '2023-09-15T14:30:00Z',
#        '_end': '2023-09-15T14:45:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F33.9',
#        'display': 'Major depressive disorder, recurrent, unspecified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ey-UndbrWgy-HOVO-1En9mIMOZA8mI-aWz7-ipR9wRm03',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'ey-UndbrWgy-HOVO-1En9mIMOZA8mI-aWz7-ipR9wRm03',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3038', 'display': 'Hazel Carter'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
#       'period': {'start': '2023-09-14T22:45:00Z',
#        '_end': '2023-09-14T23:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'E66.9',
#        'display': 'Obesity, unspecified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAE73chAQGlx1IDimAfjqk.mqeMCEa8ogtDErnPSA1ww3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eAE73chAQGlx1IDimAfjqk.mqeMCEa8ogtDErnPSA1ww3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'}],
#       'subject': {'reference': 'Patient3040', 'display': 'Nora Harris'},
#       'participant': [{'reference': 'Practitioner/Dr2001',
#         'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-09-14T19:15:00Z',
#        '_end': '2023-09-14T19:30:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.1',
#        'display': 'Generalized anxiety disorder',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eg26cvY76HBFstaRgJTij9-X4MORZvCVdIvHVNh-MEvs3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eg26cvY76HBFstaRgJTij9-X4MORZvCVdIvHVNh-MEvs3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'}],
#       'subject': {'reference': 'Patient3018', 'display': 'Owen Parker'},
#       'participant': [{'reference': 'Practitioner/Dr2005',
#         'display': 'Dr. Sophia Garcia-Richardsנ'}],
#       'period': {'start': '2023-09-14T18:45:00Z',
#        '_end': '2023-09-14T19:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'N30.00',
#        'display': 'Acute cystitis without hematuria',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAlEGs5wfHPe5k1difpAc2W7O3cN9TEztUAgtxAWcr983',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eAlEGs5wfHPe5k1difpAc2W7O3cN9TEztUAgtxAWcr983',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'}],
#       'subject': {'reference': 'Patient3026', 'display': 'Oliver White'},
#       'participant': [{'reference': 'Practitioner/Dr2001',
#         'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-09-14T18:00:00Z',
#        '_end': '2023-09-14T18:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'E66.9',
#        'display': 'Obesity, unspecified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eU7HfdlSP-w.FMOxMD6.u4CgB6VRx83BAmMZ2TN.yhfw3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eU7HfdlSP-w.FMOxMD6.u4CgB6VRx83BAmMZ2TN.yhfw3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3009', 'display': 'Daniel White'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2002', 'display': 'Dr. Benjamin Carter'}],
# ...
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3014', 'display': 'Samuel Taylor'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005',
#         'display': 'Dr. Sophia Garcia-Richardsנ'}],
#       'period': {'start': '2023-09-12T20:45:00Z',
#        '_end': '2023-09-12T21:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'R30.0',
#        'display': 'Dysuria',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e03iMAQJIVlEOAR7hyJqzrAW9sp9UXozxpkv.sOLD2f83',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'e03iMAQJIVlEOAR7hyJqzrAW9sp9UXozxpkv.sOLD2f83',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3012', 'display': 'Ava Thompson'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005',
#         'display': 'Dr. Sophia Garcia-Richardsנ'}],
#       'period': {'start': '2023-09-12T18:00:00Z',
#        '_end': '2023-09-12T18:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F33.9',
#        'display': 'Major depressive disorder, recurrent, unspecified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eu3fQL55-HyLOv9JjcTovflZJQ5Jqyl7Ab1NttIRp8Aw3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eu3fQL55-HyLOv9JjcTovflZJQ5Jqyl7Ab1NttIRp8Aw3',
#       'status': 'arrived',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3029', 'display': 'Aria Patel'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-09-12T17:15:00Z',
#        '_end': '2023-09-12T17:30:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.1',
#        'display': 'Generalized anxiety disorder',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ejaJgvmD.rGMxFvYtzQ8sIJgc1rALSnyNlBvGRIxnhFc3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'ejaJgvmD.rGMxFvYtzQ8sIJgc1rALSnyNlBvGRIxnhFc3',
#       'status': 'finished',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '111',
#           'display': 'Orders Only'}],
#         'text': 'Orders Only'}],
#       'subject': {'reference': 'Patient3032', 'display': 'Ethan Foster'},
#       'participant': [],
#       'period': {'start': '2023-08-22', '_end': '2023-08-22'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.9',
#        'display': 'Anxiety disorder, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.ydWWxFSHGiNVugaVfnGwBbSs2QipM39i8Dl2s6dqV03',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'e.ydWWxFSHGiNVugaVfnGwBbSs2QipM39i8Dl2s6dqV03',
#       'status': 'finished',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '1000',
#           'display': 'Initial consult'}],
#         'text': 'Initial consult'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200075',
#           'display': 'CONSULT'}],
#         'text': 'CONSULT'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3031', 'display': 'Madison Reed'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Amb Only Cshs, MD, MD',
#          'reference': 'Practitioner/ecgtP.6lxm5Y.5K6ma9j5PJXgP7SqWwP7l5pWLU5izAQ3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2001', 'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-08-15T21:20:00Z',
#        '_end': '2023-08-15T21:40:00Z'},
#       'location': [{'location': {'reference': 'Location/eoZBxDsF8h3swUHVxO0sxlw3',
#          'display': 'DERM LAC202 CSMG',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'N52.9',
#        'display': 'Male erectile dysfunction, unspecified',
#        'system': 'ICD-CM-10'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eZEl9vVZJI0-UmnP8SmgJ3F7dUQ-G-GK7vim8Pf.xr8E3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eZEl9vVZJI0-UmnP8SmgJ3F7dUQ-G-GK7vim8Pf.xr8E3',
#       'status': 'finished',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200414',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3038', 'display': 'Hazel Carter'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2003', 'display': 'Dr. Olivia Davis'}],
#       'period': {'start': '2023-08-16T00:45:00Z',
#        '_end': '2023-08-16T01:00:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.728286',
#           'code': '140',
#           'display': 'Goiter'}],
#         'text': 'Goiter'}],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F41.9',
#        'display': 'Anxiety disorder, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eoYNk1eig-BQDNDnmiuQLWXVMG9fqi0idBt5pjli3g0M3',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'eoYNk1eig-BQDNDnmiuQLWXVMG9fqi0idBt5pjli3g0M3',
#       'status': 'finished',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200415',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#           'code': '3',
#           'display': 'Elective'}],
#         'text': 'Elective'}],
#       'subject': {'reference': 'Patient3033', 'display': 'Avery Mitchell'},
#       'participant': [{'period': {},
#         'individual': {'display': 'Self Referred',
#          'reference': 'Practitioner/ebnVu9WHf2DdfFA-tjIoas0bHvw9Z2aZEoOkY2UodSGg3',
#          'type': 'Practitioner'},
#         'type': [{'coding': [{'system': 'http://hl7.org/fhir/v3/ParticipationType',
#             'code': 'REF',
#             'display': 'referrer'}],
#           'text': 'referrer'}],
#         'extension': []},
#        {'reference': 'Practitioner/Dr2005',
#         'display': 'Dr. Sophia Garcia-Richardsנ'}],
#       'period': {'start': '2023-08-15T16:00:00Z',
#        '_end': '2023-08-15T16:15:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'J02.9',
#        'display': 'Acute pharyngitis, unspecified',
#        'system': 'ICD-CM-9'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}},
#     {'fullurl': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.DhcIEceXUDfskTXZ2SX1LEjQc.lghPrk.hyLUgscw43',
#      'resource': {'resourcetype': 'Encounter',
#       'id': 'e.DhcIEceXUDfskTXZ2SX1LEjQc.lghPrk.hyLUgscw43',
#       'status': 'finished',
#       'type': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#           'code': '2101020001',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'},
#        {'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#           'code': '200414',
#           'display': 'Video Visit'}],
#         'text': 'Video Visit'}],
#       'subject': {'reference': 'Patient3005', 'display': 'David Brown'},
#       'participant': [{'reference': 'Practitioner/Dr2001',
#         'display': 'Dr. Emily Anderson'}],
#       'period': {'start': '2023-08-10T14:30:00Z',
#        '_end': '2023-08-10T14:45:00Z'},
#       'location': [{'location': {'reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#          'display': 'Jade Forest Hospital Center',
#          'identifier': {}},
#         'period': {},
#         'physicaltype': {'coding': []}}],
#       'reasoncode': [{'coding': [{'system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.728286',
#           'code': '148',
#           'display': 'Asthma'}],
#         'text': 'Asthma'}],
#       'issue': [],
#       'account': [],
#       'extension': [],
#       'hospitalization': {'admitsource': {'coding': []},
#        'extension': [],
#        'dischargedisposition': {'coding': []}},
#       'partof': {'identifier': {}},
#       'servicetype': {'coding': []},
#       'diagnosis': {'reference': 'F33.9',
#        'display': 'Major depressive disorder, recurrent, unspecified',
#        'system': 'ICD-CM-11'},
#       'episodeofcare': [],
#       'priority': {'coding': []}},
#      'search': {'mode': 'match'}}]},
#   'sys_insert': '2023-11-26 11:35:38.404169 UTC'}]

# %%
# Creating the relevant tables
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()


# System Inputs table - shows when the appointments were added to the DB
cursor.execute('''
    CREATE TABLE system_inputs (
        id SERIAL PRIMARY KEY,
        sys_insert TIMESTAMP WITH TIME ZONE
    )
''')


# Diagnoses table one-to-many
cursor.execute('''
    CREATE TABLE diagnosis (
        id SERIAL PRIMARY KEY,
        diagnosis_reference VARCHAR(50),
        diagnosis_name VARCHAR(100),
        system VARCHAR(50)
    )
''')


# Patients table
cursor.execute('''
    CREATE TABLE patients (
        id SERIAL PRIMARY KEY,
        patient_reference VARCHAR(50),
        patient_name VARCHAR(50)      
    )
''')

# Appointments table - Called "entries" initially but changed the table to a more descriptive name
cursor.execute('''
    CREATE TABLE appointments (
        id SERIAL PRIMARY KEY,
        status VARCHAR(50) CHECK (status IN ('arrived', 'finished')),
        appointment_url VARCHAR(300),
        start_time TIMESTAMP WITH TIME ZONE,
        end_time TIMESTAMP WITH TIME ZONE,
        system_inputs_id INTEGER,
        FOREIGN KEY (system_inputs_id) REFERENCES system_inputs(id),
        diagnosis_id INTEGER,
        FOREIGN KEY (diagnosis_id) REFERENCES diagnosis(id),
        patients_id INTEGER,
        FOREIGN KEY (patients_id) REFERENCES patients(id)

    )
''')

# Hospitals table
cursor.execute('''
    CREATE TABLE hospitals (
        id SERIAL PRIMARY KEY,
        hospital_reference VARCHAR(50),
        hospital_name VARCHAR(50)
    )
''')

# A patient might change hospital/location mid-appointment but as I wasn't sure so I relied on the fact I got the hospital in an array labeled location. So I left this also many-to-many to take care of that option.
# Many to many hospitals-appointments bridge table
cursor.execute('''
CREATE TABLE appointments_hospitals (
    appointment_id INTEGER,
    hospital_id INTEGER,
    PRIMARY KEY (appointment_id, hospital_id),
    FOREIGN KEY (appointment_id) REFERENCES appointments(id),
    FOREIGN KEY (hospital_id) REFERENCES hospitals(id)
    )
''')




# Doctors table
cursor.execute('''
    CREATE TABLE doctors (
        id SERIAL PRIMARY KEY,
        dr_reference VARCHAR(50),
        dr_name VARCHAR(50)
    )
''')

# Like in hospitals I got this data in an array and its possible one appointment has a few doctors to advise the patient.
# Many to many doctors-appointments bridge table
cursor.execute('''
CREATE TABLE doctors_appointments (
    appointment_id INTEGER,
    doctors_id INTEGER,
    PRIMARY KEY (appointment_id, doctors_id),
    FOREIGN KEY (appointment_id) REFERENCES appointments(id),
    FOREIGN KEY (doctors_id) REFERENCES doctors(id)
    )
''')





# Appointment Location table (To save the code/system/display of the appointment in case its needed)
cursor.execute('''
    CREATE TABLE locations (
        id SERIAL PRIMARY KEY,
        loc_system VARCHAR(100),
        loc_code VARCHAR(50),
        loc_display VARCHAR(50),
        appointment_id INTEGER,
        FOREIGN KEY (appointment_id) REFERENCES appointments(id)

    )
''')

conn.commit()
conn.close()

# %%
# Extracting the data from the json file
items_to_insert = []

for entry in json_fhir:
    itemToInsert = {}
    sys_insert = entry['sys_insert']
    itemToInsert['system_inputs']=sys_insert 
    entries = entry['encounter']['entry']
    visitsArr = []
    for visit in entries:
        visits = {}
        appointment_url = visit['fullurl']
        
        fixedVisit = visit['resource']
        appointment = {}
        if 'status' in fixedVisit:
            appointment_status = fixedVisit['status']
            appointment['appointment_url']=appointment_url
            appointment['appointment_status']= appointment_status
        else:
            appointment['appointment_url']=appointment_url
            appointment['appointment_status']= None
              

        if 'start' in fixedVisit['period'] and '_end' in fixedVisit['period']:
            start_time = fixedVisit['period']['start']
            end_time = fixedVisit['period']['_end']
        elif 'start' in fixedVisit['period']:
            start_time = fixedVisit['period']['start']
            end_time = None
        elif '_end' in fixedVisit['period']:
            start_time = None
            end_time = fixedVisit['period']['_end']
        else:
            start_time = end_time = None

        appointment= {**appointment, 'start_time': start_time, 'end_time': end_time}
        visits['appointment'] = appointment
        
        hospitals = fixedVisit['location']
        hospitalArr = []
        for hospital in hospitals:
            hosReference = hospital['location']['reference']
            hosDisplay = hospital['location']['display']
            hospitalArr.append({"hospital_reference": hosReference,"hospital_name":hosDisplay})
        visits['hospitals']=hospitalArr
        
        participants = fixedVisit['participant']
        drsArr = []
        for participant in participants:
            participant_reference = participant.get('reference', False)
            if participant_reference:
                isDrMatch = re.findall(r'\b(?:Dr|dr)\W*\d*\b', participant_reference)
                if isDrMatch:
                    parDisplay = participant['display']
                    drsArr.append({"dr_reference": participant_reference,"dr_name":parDisplay})
        visits['doctors']=drsArr
        
        locations = fixedVisit.get('type', [])
        locationArr = []
        for location in locations:
            coding = location.get('coding', [])
            for obj in coding:
                locSys = obj.get('system')
                locCode = obj.get('code')
                locDisplay = obj.get('display')

                if locSys and locCode and locDisplay:
                    locationArr.append({"loc_system": locSys,"loc_code": locCode,"loc_display": locDisplay})
                else:
                    locationArr.append({"loc_system": None,"loc_code": None,"loc_display": None})
        visits['locations'] = locationArr

        
        visits['diagnoses'] = {'diagnosis_reference': fixedVisit['diagnosis']['reference'], 'diagnosis_name':fixedVisit['diagnosis']['display'], 'system':fixedVisit['diagnosis']['system']}
        visits['patients'] = {'patient_reference': fixedVisit['subject']['reference'], 'patient_name':fixedVisit['subject']['display']}
        visitsArr.append(visits)
    itemToInsert['visitsArr']=visitsArr
    items_to_insert.append(itemToInsert)

items_to_insert
# Out:
# [{'system_inputs': '2023-11-26 11:35:38.404169 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F32.A',
#      'diagnosis_name': 'Depression, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3015',
#      'patient_name': 'Lily Young'}}]},
#  {'system_inputs': '2023-11-26 11:50:52.818241 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J02.9',
#      'diagnosis_name': 'Acute pharyngitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3026',
#      'patient_name': 'Oliver White'}}]},
#  {'system_inputs': '2023-11-26 14:32:21.03577 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3007',
#      'patient_name': 'William Taylor'}}]},
#  {'system_inputs': '2023-11-26 11:44:04.196978 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3008',
#      'patient_name': 'Emma Anderson'}}]},
#  {'system_inputs': '2023-11-26 12:38:33.479699 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.1',
#      'diagnosis_name': 'Generalized anxiety disorder',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3025',
#      'patient_name': 'Grace Walker'}}]},
#  {'system_inputs': '2023-11-26 14:32:21.03577 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J01.90',
#      'diagnosis_name': 'Acute sinusitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3006',
#      'patient_name': 'Sophia Martinez'}}]},
#  {'system_inputs': '2023-11-26 12:38:33.479699 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.1',
#      'diagnosis_name': 'Generalized anxiety disorder',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3002',
#      'patient_name': 'Jane Doe'}}]},
#  {'system_inputs': '2023-11-26 11:50:52.818241 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N76.0',
#      'diagnosis_name': 'Acute vaginitis',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3006',
#      'patient_name': 'Sophia Martinez'}}]},
#  {'system_inputs': '2023-11-26 11:44:04.196978 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'B37.3',
#      'diagnosis_name': 'Candidiasis of vulva and vagina',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3004',
#      'patient_name': 'Emily Johnson'}}]},
#  {'system_inputs': '2023-11-26 11:35:38.404169 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eDYzEfJtWqzyANXf5-1Efdx86jOMRWXizr-7iu.5QyG83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-22T03:00:00Z',
#      'end_time': '2023-11-22T03:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N39.0',
#      'diagnosis_name': 'Urinary tract infection, site not specified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3009',
#      'patient_name': 'Daniel White'}}]},
#  {'system_inputs': '2023-11-26 12:38:33.479699 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/esdxwR-ztD6sosLI0PIgtTA8hMDql1R-cROdOiswSDR03',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-16T20:30:00Z',
#      'end_time': '2023-11-16T20:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'K04.90',
#      'diagnosis_name': 'Unspecified diseases of pulp and periapical tissues',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3009',
#      'patient_name': 'Daniel White'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ebcOcETKr6q3F1GkMUt48D4uOXOHJGsbXp3nlJXtskno3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-06T18:45:00Z',
#      'end_time': '2023-11-06T19:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'U07.1',
#      'diagnosis_name': 'COVID-19',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3036',
#      'patient_name': 'Scarlett Johnson'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ec7u9.FNdhxp9XFKdyFg1gkEM1bAqea0HHIx4T0mVv3Y3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-02T22:45:00Z',
#      'end_time': '2023-11-02T23:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3003',
#      'patient_name': 'Michael Smith'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/elTbgsTY2x.9jPVTyMFqWcVV.3YmLrkPf2uVgCd8-AxM3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-30T12:15:00Z',
#      'end_time': '2023-10-30T12:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'I10',
#      'diagnosis_name': 'Essential (primary) hypertension',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3031',
#      'patient_name': 'Madison Reed'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ekMJg0H-ohv8r8ojv7E9SNIGcDxoLXVWVPdBB4k58odI3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-26T18:15:00Z',
#      'end_time': '2023-10-26T18:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3008',
#      'patient_name': 'Emma Anderson'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eOT2GSmkI-CWRO-2Z.dbMtPkhM7RT4W6wOvuX6oTMWXE3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-23T21:00:00Z',
#      'end_time': '2023-10-23T21:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F32.A',
#      'diagnosis_name': 'Depression, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3011',
#      'patient_name': 'Liam Harris'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/efP6ciuCLD6OkZT1u5Tb2I79igV1W91Gxc0cUQalyhyw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-15T14:45:00Z',
#      'end_time': '2023-09-15T15:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'N52.9',
#      'diagnosis_name': 'Male erectile dysfunction, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3024',
#      'patient_name': 'Elijah Davis'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e5YGOZTIbBGutvJpRf0cyOwnCuqkB0ibPuc.qk2llK8Q3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-15T14:30:00Z',
#      'end_time': '2023-09-15T14:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3030',
#      'patient_name': 'Landon Hayes'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ey-UndbrWgy-HOVO-1En9mIMOZA8mI-aWz7-ipR9wRm03',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T22:45:00Z',
#      'end_time': '2023-09-14T23:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'E66.9',
#      'diagnosis_name': 'Obesity, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3038',
#      'patient_name': 'Hazel Carter'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAE73chAQGlx1IDimAfjqk.mqeMCEa8ogtDErnPSA1ww3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T19:15:00Z',
#      'end_time': '2023-09-14T19:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'F41.1',
#      'diagnosis_name': 'Generalized anxiety disorder',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3040',
#      'patient_name': 'Nora Harris'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eg26cvY76HBFstaRgJTij9-X4MORZvCVdIvHVNh-MEvs3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T18:45:00Z',
#      'end_time': '2023-09-14T19:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'N30.00',
#      'diagnosis_name': 'Acute cystitis without hematuria',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3018',
#      'patient_name': 'Owen Parker'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAlEGs5wfHPe5k1difpAc2W7O3cN9TEztUAgtxAWcr983',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T18:00:00Z',
#      'end_time': '2023-09-14T18:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'E66.9',
#      'diagnosis_name': 'Obesity, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3026',
#      'patient_name': 'Oliver White'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eU7HfdlSP-w.FMOxMD6.u4CgB6VRx83BAmMZ2TN.yhfw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T17:00:00Z',
#      'end_time': '2023-09-14T17:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N39.0',
#      'diagnosis_name': 'Urinary tract infection, site not specified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3009',
#      'patient_name': 'Daniel White'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ecfSXnr3LJUq18l5ScOIhmK1zq926MyhMgBcqnYKcpkE3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T20:45:00Z',
#      'end_time': '2023-09-12T21:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'I10',
#      'diagnosis_name': 'Essential (primary) hypertension',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3031',
#      'patient_name': 'Madison Reed'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e03iMAQJIVlEOAR7hyJqzrAW9sp9UXozxpkv.sOLD2f83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T18:00:00Z',
#      'end_time': '2023-09-12T18:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3015',
#      'patient_name': 'Lily Young'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eu3fQL55-HyLOv9JjcTovflZJQ5Jqyl7Ab1NttIRp8Aw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T17:15:00Z',
#      'end_time': '2023-09-12T17:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N39.0',
#      'diagnosis_name': 'Urinary tract infection, site not specified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3040',
#      'patient_name': 'Nora Harris'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ejaJgvmD.rGMxFvYtzQ8sIJgc1rALSnyNlBvGRIxnhFc3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-22',
#      'end_time': '2023-08-22'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '111',
#       'loc_display': 'Orders Only'}],
#     'diagnoses': {'diagnosis_reference': 'B37.3',
#      'diagnosis_name': 'Candidiasis of vulva and vagina',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3010',
#      'patient_name': 'Olivia Davis'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.ydWWxFSHGiNVugaVfnGwBbSs2QipM39i8Dl2s6dqV03',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-15T21:20:00Z',
#      'end_time': '2023-08-15T21:40:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/eoZBxDsF8h3swUHVxO0sxlw3',
#       'hospital_name': 'DERM LAC202 CSMG'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '1000',
#       'loc_display': 'Initial consult'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200075',
#       'loc_display': 'CONSULT'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3016',
#      'patient_name': 'Alexander White'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eZEl9vVZJI0-UmnP8SmgJ3F7dUQ-G-GK7vim8Pf.xr8E3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-16T00:45:00Z',
#      'end_time': '2023-08-16T01:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200414',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'K04.90',
#      'diagnosis_name': 'Unspecified diseases of pulp and periapical tissues',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3041',
#      'patient_name': 'Ethan Fisher'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eoYNk1eig-BQDNDnmiuQLWXVMG9fqi0idBt5pjli3g0M3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-15T16:00:00Z',
#      'end_time': '2023-08-15T16:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N52.9',
#      'diagnosis_name': 'Male erectile dysfunction, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3001',
#      'patient_name': 'John Doe'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.DhcIEceXUDfskTXZ2SX1LEjQc.lghPrk.hyLUgscw43',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-10T14:30:00Z',
#      'end_time': '2023-08-10T14:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200414',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'N30.0',
#      'diagnosis_name': 'Acute cystitis',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3030',
#      'patient_name': 'Landon Hayes'}}]},
#  {'system_inputs': '2023-11-26 11:35:38.404169 UTC',
#   'visitsArr': [{'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/esdxwR-ztD6sosLI0PIgtTA8hMDql1R-cROdOiswSDR03',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-16T20:30:00Z',
#      'end_time': '2023-11-16T20:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F32.9',
#      'diagnosis_name': 'Major depressive disorder, single episode, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3030',
#      'patient_name': 'Landon Hayes'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ebcOcETKr6q3F1GkMUt48D4uOXOHJGsbXp3nlJXtskno3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-06T18:45:00Z',
#      'end_time': '2023-11-06T19:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J02.9',
#      'diagnosis_name': 'Acute pharyngitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3010',
#      'patient_name': 'Olivia Davis'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ec7u9.FNdhxp9XFKdyFg1gkEM1bAqea0HHIx4T0mVv3Y3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-11-02T22:45:00Z',
#      'end_time': '2023-11-02T23:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3010',
#      'patient_name': 'Olivia Davis'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/elTbgsTY2x.9jPVTyMFqWcVV.3YmLrkPf2uVgCd8-AxM3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-30T12:15:00Z',
#      'end_time': '2023-10-30T12:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J06.9',
#      'diagnosis_name': 'Acute upper respiratory infection, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3005',
#      'patient_name': 'David Brown'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ekMJg0H-ohv8r8ojv7E9SNIGcDxoLXVWVPdBB4k58odI3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-26T18:15:00Z',
#      'end_time': '2023-10-26T18:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J01.90',
#      'diagnosis_name': 'Acute sinusitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3044',
#      'patient_name': 'Isabella Lee'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eOT2GSmkI-CWRO-2Z.dbMtPkhM7RT4W6wOvuX6oTMWXE3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-10-23T21:00:00Z',
#      'end_time': '2023-10-23T21:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N52.9',
#      'diagnosis_name': 'Male erectile dysfunction, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3028',
#      'patient_name': 'Mason Brown'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/efP6ciuCLD6OkZT1u5Tb2I79igV1W91Gxc0cUQalyhyw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-15T14:45:00Z',
#      'end_time': '2023-09-15T15:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3015',
#      'patient_name': 'Lily Young'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e5YGOZTIbBGutvJpRf0cyOwnCuqkB0ibPuc.qk2llK8Q3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-15T14:30:00Z',
#      'end_time': '2023-09-15T14:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2002',
#       'dr_name': 'Dr. Benjamin Carter'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3013',
#      'patient_name': 'Mia Walker'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ey-UndbrWgy-HOVO-1En9mIMOZA8mI-aWz7-ipR9wRm03',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T22:45:00Z',
#      'end_time': '2023-09-14T23:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N39.0',
#      'diagnosis_name': 'Urinary tract infection, site not specified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3008',
#      'patient_name': 'Emma Anderson'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAE73chAQGlx1IDimAfjqk.mqeMCEa8ogtDErnPSA1ww3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T19:15:00Z',
#      'end_time': '2023-09-14T19:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'J01.90',
#      'diagnosis_name': 'Acute sinusitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3028',
#      'patient_name': 'Mason Brown'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eg26cvY76HBFstaRgJTij9-X4MORZvCVdIvHVNh-MEvs3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T18:45:00Z',
#      'end_time': '2023-09-14T19:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'I10',
#      'diagnosis_name': 'Essential (primary) hypertension',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3017',
#      'patient_name': 'Grace Nelson'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAlEGs5wfHPe5k1difpAc2W7O3cN9TEztUAgtxAWcr983',
# ...
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3001',
#      'patient_name': 'John Doe'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e5YGOZTIbBGutvJpRf0cyOwnCuqkB0ibPuc.qk2llK8Q3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-15T14:30:00Z',
#      'end_time': '2023-09-15T14:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'U07.1',
#      'diagnosis_name': 'COVID-19',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3029',
#      'patient_name': 'Aria Patel'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ey-UndbrWgy-HOVO-1En9mIMOZA8mI-aWz7-ipR9wRm03',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T22:45:00Z',
#      'end_time': '2023-09-14T23:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F32.A',
#      'diagnosis_name': 'Depression, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3020',
#      'patient_name': 'Benjamin Carter'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAE73chAQGlx1IDimAfjqk.mqeMCEa8ogtDErnPSA1ww3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T19:15:00Z',
#      'end_time': '2023-09-14T19:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3041',
#      'patient_name': 'Ethan Fisher'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eg26cvY76HBFstaRgJTij9-X4MORZvCVdIvHVNh-MEvs3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T18:45:00Z',
#      'end_time': '2023-09-14T19:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2004',
#       'dr_name': 'Dr. Ethan Fisher'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3005',
#      'patient_name': 'David Brown'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eAlEGs5wfHPe5k1difpAc2W7O3cN9TEztUAgtxAWcr983',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T18:00:00Z',
#      'end_time': '2023-09-14T18:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'E66.9',
#      'diagnosis_name': 'Obesity, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3016',
#      'patient_name': 'Alexander White'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eU7HfdlSP-w.FMOxMD6.u4CgB6VRx83BAmMZ2TN.yhfw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-14T17:00:00Z',
#      'end_time': '2023-09-14T17:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F32.9',
#      'diagnosis_name': 'Major depressive disorder, single episode, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3037',
#      'patient_name': 'Lucas Kelly'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ecfSXnr3LJUq18l5ScOIhmK1zq926MyhMgBcqnYKcpkE3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T20:45:00Z',
#      'end_time': '2023-09-12T21:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'R30.0',
#      'diagnosis_name': 'Dysuria',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3014',
#      'patient_name': 'Samuel Taylor'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e03iMAQJIVlEOAR7hyJqzrAW9sp9UXozxpkv.sOLD2f83',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T18:00:00Z',
#      'end_time': '2023-09-12T18:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3012',
#      'patient_name': 'Ava Thompson'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eu3fQL55-HyLOv9JjcTovflZJQ5Jqyl7Ab1NttIRp8Aw3',
#      'appointment_status': 'arrived',
#      'start_time': '2023-09-12T17:15:00Z',
#      'end_time': '2023-09-12T17:30:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.1',
#      'diagnosis_name': 'Generalized anxiety disorder',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3029',
#      'patient_name': 'Aria Patel'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/ejaJgvmD.rGMxFvYtzQ8sIJgc1rALSnyNlBvGRIxnhFc3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-22',
#      'end_time': '2023-08-22'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '111',
#       'loc_display': 'Orders Only'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3032',
#      'patient_name': 'Ethan Foster'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.ydWWxFSHGiNVugaVfnGwBbSs2QipM39i8Dl2s6dqV03',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-15T21:20:00Z',
#      'end_time': '2023-08-15T21:40:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/eoZBxDsF8h3swUHVxO0sxlw3',
#       'hospital_name': 'DERM LAC202 CSMG'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '1000',
#       'loc_display': 'Initial consult'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200075',
#       'loc_display': 'CONSULT'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'N52.9',
#      'diagnosis_name': 'Male erectile dysfunction, unspecified',
#      'system': 'ICD-CM-10'},
#     'patients': {'patient_reference': 'Patient3031',
#      'patient_name': 'Madison Reed'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eZEl9vVZJI0-UmnP8SmgJ3F7dUQ-G-GK7vim8Pf.xr8E3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-16T00:45:00Z',
#      'end_time': '2023-08-16T01:00:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2003',
#       'dr_name': 'Dr. Olivia Davis'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200414',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'F41.9',
#      'diagnosis_name': 'Anxiety disorder, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3038',
#      'patient_name': 'Hazel Carter'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/eoYNk1eig-BQDNDnmiuQLWXVMG9fqi0idBt5pjli3g0M3',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-15T16:00:00Z',
#      'end_time': '2023-08-15T16:15:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2005',
#       'dr_name': 'Dr. Sophia Garcia-Richardsנ'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200415',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.18875',
#       'loc_code': '3',
#       'loc_display': 'Elective'}],
#     'diagnoses': {'diagnosis_reference': 'J02.9',
#      'diagnosis_name': 'Acute pharyngitis, unspecified',
#      'system': 'ICD-CM-9'},
#     'patients': {'patient_reference': 'Patient3033',
#      'patient_name': 'Avery Mitchell'}},
#    {'appointment': {'appointment_url': 'https://jade-forest-h.edu/sup-fhirproxy/api/FHIR/R4/Encounter/e.DhcIEceXUDfskTXZ2SX1LEjQc.lghPrk.hyLUgscw43',
#      'appointment_status': 'finished',
#      'start_time': '2023-08-10T14:30:00Z',
#      'end_time': '2023-08-10T14:45:00Z'},
#     'hospitals': [{'hospital_reference': 'Location/emFR3fX6yqT.KL--hFHkxMw3',
#       'hospital_name': 'Jade Forest Hospital Center'}],
#     'doctors': [{'dr_reference': 'Practitioner/Dr2001',
#       'dr_name': 'Dr. Emily Anderson'}],
#     'locations': [{'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.10.698084.30',
#       'loc_code': '2101020001',
#       'loc_display': 'Video Visit'},
#      {'loc_system': 'urn:oid:1.2.998.1251.341.13.202.3.7.2.808267',
#       'loc_code': '200414',
#       'loc_display': 'Video Visit'}],
#     'diagnoses': {'diagnosis_reference': 'F33.9',
#      'diagnosis_name': 'Major depressive disorder, recurrent, unspecified',
#      'system': 'ICD-CM-11'},
#     'patients': {'patient_reference': 'Patient3005',
#      'patient_name': 'David Brown'}}]}]

# %%
# Adding the data to the tables that were created

systemDataToInsert = []

for index,item in enumerate(items_to_insert):
    timestamp_str = item['system_inputs'] 
    parts = timestamp_str.split('.')
    date_time = parts[0]  
    
    milliseconds = parts[1].split()[0] if len(parts) > 1 else '000000' 
    if len(milliseconds) < 6:
        milliseconds = milliseconds + "0"

    timestamp_str = f"{date_time}.{milliseconds} {'UTC' if len(parts) > 1 else ''}"
    timestamp = arrow.get(timestamp_str, 'YYYY-MM-DD HH:mm:ss.SSSSSS ZZZ').datetime

    systemDataToInsert.append({'sys_insert': timestamp})

conn = psycopg2.connect(
dbname="FHIR",
user="postgres",
password="password",
host="localhost",
port="5432")

cursor = conn.cursor()

values = [(item['sys_insert'],) for item in systemDataToInsert]

sql = 'INSERT INTO public.system_inputs (sys_insert) VALUES %s RETURNING id'

results = extras.execute_values(cursor, sql, values, fetch=True)

conn.commit()
conn.close()

# %%
ind_list = [result[0] for result in results]

appointmentsToInsert = []

for index, item in enumerate(items_to_insert):
    visitArr = item['visitsArr']
    for visit in visitsArr:
        appointments = visit['appointment']
        appointmentsToInsert.append({'system_inputs_id': ind_list[index],'appointment_url': appointments['appointment_url'],
                                     'status':appointments['appointment_status'], 'start_time':appointments['start_time'],
                                    'end_time':appointments['end_time']})    

 
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO appointments (status, appointment_url, start_time, end_time, system_inputs_id) VALUES %s RETURNING id'
values = [(
        appointment['status'],
        appointment['appointment_url'],
        appointment['start_time'],
        appointment['end_time'],
        appointment['system_inputs_id']
    )
    for appointment in appointmentsToInsert]

idOfAppointments = extras.execute_values(cursor, sql, values, fetch=True)
conn.commit()
conn.close()

# %%
ind_list = [ind[0] for ind in idOfAppointments]


doctorValue = []
# [{},{}]
appointmentIdToConnToDr = []
# [[5,3],[1,2,4]]

#  index count helps us see how many appointments we iterated through in order to get the correct index of the appointment id inside the above array
indexCount=0 
for index,item in enumerate(items_to_insert):
    visitArr = item['visitsArr']
    for visitIndex, visit in enumerate(visitsArr):
        doctors= visit['doctors']
        for dr in doctors:
            index = next((idx for idx, drToCheck in enumerate(doctorValue) if drToCheck['dr_reference'] == dr['dr_reference']), None)
            if index is not None:
                if len(appointmentIdToConnToDr) > index:
                    appointmentIdToConnToDr[index].append(ind_list[indexCount])
                else:
                    print('error not enough indexes - Should not happen')
            else:
                doctorValue.append({'dr_reference': dr['dr_reference'], 'dr_name':dr['dr_name']})
                appointmentIdToConnToDr.append([ind_list[indexCount]])
        indexCount+=1
       
 
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO doctors (dr_reference, dr_name) VALUES %s RETURNING id'
values = [(
        doctor['dr_reference'],
        doctor['dr_name']
    )
    for doctor in doctorValue]

idOfDoctors = extras.execute_values(cursor, sql, values, fetch=True)
conn.commit()




idOfDoctors
# Out:
# [(1,), (2,), (3,), (4,), (5,)]

# %%
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

# preparing the data to insert into the bridge
dr_ind_list = [ind[0] for ind in idOfDoctors]

bridgeValuesToEnter= []

for indexOfDrId, appntArr in enumerate(appointmentIdToConnToDr):
    for appntId in appntArr:
        bridgeValuesToEnter.append({'dr_id':dr_ind_list[indexOfDrId],'appnt_id':appntId})
        
        
sqlBridge = "INSERT INTO doctors_appointments (appointment_id, doctors_id) VALUES %s"

valuesBridge = [(
        bridgeVal['appnt_id'],
        bridgeVal['dr_id']
    )
    for bridgeVal in bridgeValuesToEnter]

extras.execute_values(cursor, sqlBridge, valuesBridge)
conn.commit()

# %%
ind_list = [ind[0] for ind in idOfAppointments]

hospitalValue = []
# [{},{}]
appointmentIdToConnToHos = []
# [[5,3],[1,2,4]]

indexCount=0
for item in items_to_insert:
    visitArr = item['visitsArr']
    for visitIndex, visit in enumerate(visitsArr):
        hospitals= visit['hospitals']
        for hospital in hospitals:
            index = next((idx for idx, hosToCheck in enumerate(hospitalValue) if hosToCheck['hospital_reference'] == hospital['hospital_reference']), None)
            if index is not None:
                if len(appointmentIdToConnToHos) > index:
                    appointmentIdToConnToHos[index].append(ind_list[indexCount])
                else:
                    print('error not enough indexes - Should not happen')
            else:
                hospitalValue.append({'hospital_reference': hospital['hospital_reference'], 'hospital_name':hospital['hospital_name']})
                appointmentIdToConnToHos.append([ind_list[indexCount]])
        indexCount+=1
       

 
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO hospitals (hospital_reference, hospital_name) VALUES %s RETURNING id'
values = [(
        hospital['hospital_reference'],
        hospital['hospital_name']
    )
    for hospital in hospitalValue]

idOfHospitals = extras.execute_values(cursor, sql, values, fetch=True)
conn.commit()

# %%
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

# preparing the data to insert into the bridge
hos_ind_list = [ind[0] for ind in idOfHospitals]

bridgeValuesToEnter= []

for indexOfHosId, appntArr in enumerate(appointmentIdToConnToHos):
    for appntId in appntArr:
        bridgeValuesToEnter.append({'hos_id':hos_ind_list[indexOfHosId],'appnt_id':appntId})
        
        
sqlBridge = "INSERT INTO appointments_hospitals (appointment_id, hospital_id) VALUES %s"

valuesBridge = [(
        bridgeVal['appnt_id'],
        bridgeVal['hos_id']
    )
    for bridgeVal in bridgeValuesToEnter]

extras.execute_values(cursor, sqlBridge, valuesBridge)
conn.commit()

# %%
ind_list = [ind[0] for ind in idOfAppointments]

locationValue = []

indexCount=0
for index,item in enumerate(items_to_insert):
    visitArr = item['visitsArr']
    for visitIndex, visit in enumerate(visitsArr):
        locations= visit['locations']
        for loc in locations:
            locationValue.append({'loc_system': loc['loc_system'], 'loc_code':loc['loc_code'],'loc_display':loc['loc_display'], 'appointment_id':ind_list[indexCount]})
        indexCount+=1
       

conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO locations (loc_system, loc_code, loc_display, appointment_id) VALUES %s RETURNING id'
values = [(
        loc['loc_system'],
        loc['loc_code'],
        loc['loc_display'],
        loc['appointment_id']
    )
    for loc in locationValue]

extras.execute_values(cursor, sql, values, fetch=True)
conn.commit()

# %%
ind_list = [ind[0] for ind in idOfAppointments]

diagnosesUniqueValue = []
# [{},{}]
repeatDiagnosesAccordingToAppnt = []
# mantains index of the id correlated to with id of appointment

indexCount = 0
for item in items_to_insert:
    visitArr = item['visitsArr']
    for visit in visitsArr:
        diagnosis= visit['diagnoses']
        diagObj = {'diagnosis_reference': diagnosis['diagnosis_reference'], 'diagnosis_name':diagnosis['diagnosis_name'],'system':diagnosis['system']}
        index = next((idx for idx, diagToCheck in enumerate(diagnosesUniqueValue) if diagToCheck['diagnosis_reference'] == diagnosis['diagnosis_reference']), None)
        if index is None:
            diagnosesUniqueValue.append(diagObj)
        repeatDiagnosesAccordingToAppnt.append(diagObj)
    indexCount+=1
        
        
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO diagnosis (diagnosis_reference, diagnosis_name, system) VALUES %s RETURNING id'
values = [(
        diag['diagnosis_reference'],
        diag['diagnosis_name'],
        diag['system']
    )
    for diag in diagnosesUniqueValue]

idOfDiag= extras.execute_values(cursor, sql, values, fetch=True)


conn.commit()

# %%
appnt_id_list = [ind[0] for ind in idOfAppointments]
diag_id_list = [ind[0] for ind in idOfDiag]

# print(diagnosesValue) the order it was entered into the db
print(len(appnt_id_list))
print(len(diag_id_list))
print(len(diagnosesUniqueValue))
arrayOfAppntConToDiag =  [[] for _ in range(len(diagnosesUniqueValue))] # empty array according to length to order according to diag id with its index
# indexed based on diagnoses with array of appnt connected to
for indexOfAppnt, diag in enumerate(repeatDiagnosesAccordingToAppnt):
    indexOfEnteredToDbDiagnosis = next((index for index, diagnos in enumerate(diagnosesUniqueValue) if diagnos['diagnosis_reference'] == diag['diagnosis_reference']), None)
    if indexOfEnteredToDbDiagnosis is not None:
        arrayOfAppntConToDiag[indexOfEnteredToDbDiagnosis].append(appnt_id_list[indexOfAppnt])
    else:
        print('error should not happen, didnt find index of referenced diagnosis')
        

updAppnt = []

for indexOfDiag, arrAppnt in enumerate(arrayOfAppntConToDiag):
    for appntIds in arrAppnt:
        updAppnt.append({'diagId':diag_id_list[indexOfDiag],'appntId':appntIds})

conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

values = [(apnt['diagId'], apnt['appntId']) for apnt in updAppnt]

sql = 'UPDATE appointments SET diagnosis_id = %s WHERE id = %s'

extras.execute_batch(cursor, sql, values)


conn.commit()
# Out:
# 1000
# 11
# 11

# %%
ind_list = [ind[0] for ind in idOfAppointments]

patientsUniqueValue = []
# [{},{}]
repeatPatientsAccordingToAppnt = []
# mantains index of the id correlated to with id of appointment

indexCount = 0
for item in items_to_insert:
    visitArr = item['visitsArr']
    for visit in visitsArr:
        patient= visit['patients']
        patientObj = {'patient_reference': patient['patient_reference'], 'patient_name':patient['patient_name']}
        index = next((idx for idx, patToCheck in enumerate(patientsUniqueValue) if patToCheck['patient_reference'] == patientObj['patient_reference']), None)
        if index is None:
            patientsUniqueValue.append(patientObj)
        repeatPatientsAccordingToAppnt.append(patientObj)
    indexCount+=1
        
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

sql = 'INSERT INTO patients (patient_reference, patient_name) VALUES %s RETURNING id'
values = [(
        pt['patient_reference'],
        pt['patient_name']
    )
    for pt in patientsUniqueValue]

patientIds = extras.execute_values(cursor, sql, values, fetch=True)


conn.commit()

# %%
appnt_id_list = [ind[0] for ind in idOfAppointments]
pat_id_list = [ind[0] for ind in patientIds]



arrayOfAppntConToPat =  [[] for _ in range(len(patientsUniqueValue))] # empty array according to length to order according to patient id with its index
# indexed based on patients with array of appnt connected to
for indexOfAppnt, patient in enumerate(repeatPatientsAccordingToAppnt):
    indexOfEnteredToDbPatients = next((index for index, patToCheck in enumerate(patientsUniqueValue) if patToCheck['patient_reference'] == patient['patient_reference']), None)
    if indexOfEnteredToDbPatients is not None:
        arrayOfAppntConToPat[indexOfEnteredToDbPatients].append(appnt_id_list[indexOfAppnt])
    else:
        print('error should not happen, didnt find index of referenced diagnosis')
        

updAppnt = []

for indexOfPat, arrAppnt in enumerate(arrayOfAppntConToPat):
    for appntIds in arrAppnt:
        updAppnt.append({'patId':pat_id_list[indexOfPat],'appntId':appntIds})
        
print(updAppnt)
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

values = [(apnt['patId'], apnt['appntId']) for apnt in updAppnt]

sql = 'UPDATE appointments SET patients_id = %s WHERE id = %s'


extras.execute_batch(cursor, sql, values)


conn.commit()
# Out:
# [{'patId': 1, 'appntId': 1}, {'patId': 1, 'appntId': 21}, {'patId': 1, 'appntId': 41}, {'patId': 1, 'appntId': 61}, {'patId': 1, 'appntId': 81}, {'patId': 1, 'appntId': 101}, {'patId': 1, 'appntId': 121}, {'patId': 1, 'appntId': 141}, {'patId': 1, 'appntId': 161}, {'patId': 1, 'appntId': 181}, {'patId': 1, 'appntId': 201}, {'patId': 1, 'appntId': 221}, {'patId': 1, 'appntId': 241}, {'patId': 1, 'appntId': 261}, {'patId': 1, 'appntId': 281}, {'patId': 1, 'appntId': 301}, {'patId': 1, 'appntId': 321}, {'patId': 1, 'appntId': 341}, {'patId': 1, 'appntId': 361}, {'patId': 1, 'appntId': 381}, {'patId': 1, 'appntId': 401}, {'patId': 1, 'appntId': 421}, {'patId': 1, 'appntId': 441}, {'patId': 1, 'appntId': 461}, {'patId': 1, 'appntId': 481}, {'patId': 1, 'appntId': 501}, {'patId': 1, 'appntId': 521}, {'patId': 1, 'appntId': 541}, {'patId': 1, 'appntId': 561}, {'patId': 1, 'appntId': 581}, {'patId': 1, 'appntId': 601}, {'patId': 1, 'appntId': 621}, {'patId': 1, 'appntId': 641}, {'patId': 1, 'appntId': 661}, {'patId': 1, 'appntId': 681}, {'patId': 1, 'appntId': 701}, {'patId': 1, 'appntId': 721}, {'patId': 1, 'appntId': 741}, {'patId': 1, 'appntId': 761}, {'patId': 1, 'appntId': 781}, {'patId': 1, 'appntId': 801}, {'patId': 1, 'appntId': 821}, {'patId': 1, 'appntId': 841}, {'patId': 1, 'appntId': 861}, {'patId': 1, 'appntId': 881}, {'patId': 1, 'appntId': 901}, {'patId': 1, 'appntId': 921}, {'patId': 1, 'appntId': 941}, {'patId': 1, 'appntId': 961}, {'patId': 1, 'appntId': 981}, {'patId': 2, 'appntId': 2}, {'patId': 2, 'appntId': 22}, {'patId': 2, 'appntId': 42}, {'patId': 2, 'appntId': 62}, {'patId': 2, 'appntId': 82}, {'patId': 2, 'appntId': 102}, {'patId': 2, 'appntId': 122}, {'patId': 2, 'appntId': 142}, {'patId': 2, 'appntId': 162}, {'patId': 2, 'appntId': 182}, {'patId': 2, 'appntId': 202}, {'patId': 2, 'appntId': 222}, {'patId': 2, 'appntId': 242}, {'patId': 2, 'appntId': 262}, {'patId': 2, 'appntId': 282}, {'patId': 2, 'appntId': 302}, {'patId': 2, 'appntId': 322}, {'patId': 2, 'appntId': 342}, {'patId': 2, 'appntId': 362}, {'patId': 2, 'appntId': 382}, {'patId': 2, 'appntId': 402}, {'patId': 2, 'appntId': 422}, {'patId': 2, 'appntId': 442}, {'patId': 2, 'appntId': 462}, {'patId': 2, 'appntId': 482}, {'patId': 2, 'appntId': 502}, {'patId': 2, 'appntId': 522}, {'patId': 2, 'appntId': 542}, {'patId': 2, 'appntId': 562}, {'patId': 2, 'appntId': 582}, {'patId': 2, 'appntId': 602}, {'patId': 2, 'appntId': 622}, {'patId': 2, 'appntId': 642}, {'patId': 2, 'appntId': 662}, {'patId': 2, 'appntId': 682}, {'patId': 2, 'appntId': 702}, {'patId': 2, 'appntId': 722}, {'patId': 2, 'appntId': 742}, {'patId': 2, 'appntId': 762}, {'patId': 2, 'appntId': 782}, {'patId': 2, 'appntId': 802}, {'patId': 2, 'appntId': 822}, {'patId': 2, 'appntId': 842}, {'patId': 2, 'appntId': 862}, {'patId': 2, 'appntId': 882}, {'patId': 2, 'appntId': 902}, {'patId': 2, 'appntId': 922}, {'patId': 2, 'appntId': 942}, {'patId': 2, 'appntId': 962}, {'patId': 2, 'appntId': 982}, {'patId': 3, 'appntId': 3}, {'patId': 3, 'appntId': 14}, {'patId': 3, 'appntId': 23}, {'patId': 3, 'appntId': 34}, {'patId': 3, 'appntId': 43}, {'patId': 3, 'appntId': 54}, {'patId': 3, 'appntId': 63}, {'patId': 3, 'appntId': 74}, {'patId': 3, 'appntId': 83}, {'patId': 3, 'appntId': 94}, {'patId': 3, 'appntId': 103}, {'patId': 3, 'appntId': 114}, {'patId': 3, 'appntId': 123}, {'patId': 3, 'appntId': 134}, {'patId': 3, 'appntId': 143}, {'patId': 3, 'appntId': 154}, {'patId': 3, 'appntId': 163}, {'patId': 3, 'appntId': 174}, {'patId': 3, 'appntId': 183}, {'patId': 3, 'appntId': 194}, {'patId': 3, 'appntId': 203}, {'patId': 3, 'appntId': 214}, {'patId': 3, 'appntId': 223}, {'patId': 3, 'appntId': 234}, {'patId': 3, 'appntId': 243}, {'patId': 3, 'appntId': 254}, {'patId': 3, 'appntId': 263}, {'patId': 3, 'appntId': 274}, {'patId': 3, 'appntId': 283}, {'patId': 3, 'appntId': 294}, {'patId': 3, 'appntId': 303}, {'patId': 3, 'appntId': 314}, {'patId': 3, 'appntId': 323}, {'patId': 3, 'appntId': 334}, {' ...

# %%
#First query

conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

cursor.execute("SELECT DISTINCT patient_reference, patient_name FROM patients")

patient_info = cursor.fetchall()

cursor.close()
conn.close()

with open('patient_info.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Patient Reference', 'Patient Name'])
    for patient in patient_info:
        writer.writerow(patient)

print("CSV file 'patient_info.csv' has been created with patient information.")
# Out:
# CSV file 'patient_info.csv' has been created with patient information.

# %%
#Second query

conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432"
)
cursor = conn.cursor()

cursor.execute("""
    SELECT patients.patient_name, COUNT(appointments.id) AS appointment_count
    FROM patients
    JOIN appointments ON patients.id = appointments.patients_id
    GROUP BY patients.patient_name
""")

patient_info = cursor.fetchall()

cursor.close()
conn.close()

with open('appointments_count.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Patient Name', 'Appointment Count'])
    for patient in patient_info:
        writer.writerow(patient)

print("CSV file 'appointments_count.csv' has been created with patient appointment counts.")
# Out:
# CSV file 'appointments_count.csv' has been created with patient appointment counts.

# %%
#Third query

conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432"
)

cursor = conn.cursor()

cursor.execute('''
    SELECT d.dr_name AS practitioner_name, COUNT(da.appointment_id) AS encounter_count
    FROM doctors d
    JOIN doctors_appointments da ON d.id = da.doctors_id
    GROUP BY d.dr_name
    ORDER BY encounter_count DESC
    LIMIT 1
''')

result = cursor.fetchone()

if result:
    practitioner_name, encounter_count = result
    print(f"The practitioner '{practitioner_name}' has the highest number of encounters: {encounter_count}")
else:
    print("No data found.")

cursor.close()
conn.close()
# Out:
# The practitioner 'Dr. Sophia Garcia-Richardsנ' has the highest number of encounters: 400

# %%
conn = psycopg2.connect(
    dbname="FHIR",
    user="postgres",
    password="password",
    host="localhost",
    port="5432")

cursor = conn.cursor()

cursor.execute('''
    SELECT month, condition, condition_count
    FROM (
        SELECT EXTRACT(MONTH FROM start_time) AS month,
               diagnosis.diagnosis_name AS condition,
               COUNT(*) AS condition_count,
               ROW_NUMBER() OVER (PARTITION BY EXTRACT(MONTH FROM start_time) ORDER BY COUNT(*) DESC) AS rn
        FROM appointments
        JOIN diagnosis ON appointments.diagnosis_id = diagnosis.id
        GROUP BY month, condition
    ) sub
    WHERE rn = 1
    ORDER BY month
''')

results = cursor.fetchall()

csv_filename = "common_conditions_per_month.csv"

with open(csv_filename, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['Month', 'Condition', 'Condition Count'])

    for row in results:
        month, condition, condition_count = row
        csv_writer.writerow([month, condition, condition_count])

print(f"Results saved to '{csv_filename}'")

cursor.close()
conn.close()
# Out:
# Results saved to 'common_conditions_per_month.csv'
